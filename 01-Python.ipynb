# %%
print("Hello world")
# Out:
# Hello world

# %%
input("enter the name ")
# Out:
# enter the name Aadil Reyaz
# 'Aadil Reyaz'

# %%
a = input("enter the name: ")
b = input("enter the age: ")
print("Hi! This is {} and my age is {}".format(a,b))
# Out:
# enter the name: aadil
# enter the age: 22
# Hi! This is aadil and my age is 22

# %%
a = input("enter the name: ")            # we can add string and variable
b = input("enter the age: ")
print("Hi! This is " + a + " and age is " + b)
# Out:
# enter the name: aadil
# enter the age: 22
# Hi! This is aadil and age is 22

# %% [markdown]
# # Variable

# %%
x = "Python is"
y = "awesome"
print(x + " " + y)
# Out:
# Python is awesome

# %%
x = 5
y = (str(x))                          #typecasting
print(type(y))                        #type fn
# Out:
# <class 'str'>

# %%
x = 12
y = 15
print(x + y)
# Out:
# 27

# %%
x = 10
x = "Sally"
print(x)
# Out:
# Sally

# %%
x = y = z = "Apple"
print(x)
print(y)
print(z)
# Out:
# Apple
# Apple
# Apple

# %%
x, y, z = "apple", "banana", "cherry"
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
fruits = ["apple", "Banana", "Cherry"]                          # unpacking from List or tuples
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# Banana
# Cherry

# %%
x = "Aadil" # Global variable

def myfunc():
    print("My name is " + x)
    
myfunc()
# Out:
# My name is Aadil

# %% [markdown]
# # String

# %%
x = "Python is popular progarmming lanuange which is used Data science and Machine learning"
print(x)
# Out:
# Python is popular progarmming lanuange which is used Data science and Machine learning

# %%
a = "Programming"

# %%
a[2]
# Out:
# 'o'

# %%
a[7]
# Out:
# 'm'

# %%
a[3:8]
# Out:
# 'gramm'

# %%
a[-4:-2]
# Out:
# 'mi'

# %%
len(a)
# Out:
# 11

# %%
x
# Out:
# 'Python is popular progarmming lanuange which is used Data science and Machine learning'

# %%
"popular" in x # check text
# Out:
# True

# %%
"Artificial intelligence" in x
# Out:
# False

# %%
y = "I love India and all Indian are talented"
if "love" in y:
    print("I am proud of India")
# Out:
# I am proud of India

# %%
y = "I love India and all Indian are talented"
if "like" in y:
    print("I am proud of India")
else:
      print("I love my country")
# Out:
# I love my country

# %%
for x in "apple":                                       # looping through x
    print(x)
# Out:
# a
# p
# p
# l
# e

# %%
a
# Out:
# 'Programming'

# %%
a.upper()
# Out:
# 'PROGRAMMING'

# %%
a.lower()
# Out:
# 'programming'

# %%
z = "Hello world  "
z
# Out:
# 'Hello world  '

# %%
z.strip()                                          # strip fn removes white space
# Out:
# 'Hello world'

# %%
z.replace('Hello', 'Hi')
# Out:
# 'Hi world  '

# %%
z.split()                                         # split fn splits into strings
# Out:
# ['Hello', 'world']

# %%
p = 25                                            # to add string and integer we use format fn
txt = "He is Mohan and his age is {}."
print(txt.format(p))
# Out:
# He is Mohan and his age is 25.

# %%
x = "I am \"King\" in the north. I am loved by people"
print(x)
# Out:
# I am "King" in the north. I am loved by people

# %%
x = "I am King in the north. \nI am loved by people"
print(x)
# Out:
# I am King in the north.
# I am loved by people

# %%
x = "Hello\tworld"
print(x)
# Out:
# Hello	world

# %%
x = "Hello \\ world"
print(x)
# Out:
# Hello \ world

# %%
y
# Out:
# 'I love India and all Indian are talented'

# %%
y.find("all")
# Out:
# 17

# %%
y.count("are")
# Out:
# 1

# %%
y.index("all")
# Out:
# 17

# %%
y.casefold()
# Out:
# 'i love india and all indian are talented'

# %%
y.capitalize()
# Out:
# 'I love india and all indian are talented'

# %% [markdown]
# # Boolean

# %%
5>2
# Out:
# True

# %%
2 >3
# Out:
# False

# %%
x = 500
y = 300
if y > x:
    print('y is greater than x')
else:
    print("x is greater than y")
# Out:
# x is greater than y

# %% [markdown]
# # Operators

# %%
5 + 3
# Out:
# 8

# %%
4-4
# Out:
# 0

# %%
a = 6
a += 4
a
# Out:
# 10

# %%
10/2
# Out:
# 5.0

# %%
11%5           # modulus gives remainder
# Out:
# 1

# %%
11//5
# Out:
# 2

# %%
4**4
# Out:
# 256

# %%
a = 6
a -= 4
a
# Out:
# 2

# %%
a = 10
a/=5
a
# Out:
# 2.0

# %%
5 > 7
# Out:
# False

# %%
3>1
# Out:
# True

# %%
23>6 and 45<56
# Out:
# True

# %%
45>23 or 56>5
# Out:
# True

# %%
not(45>23 or 56>5)
# Out:
# False

# %%
5 !=7
# Out:
# True
